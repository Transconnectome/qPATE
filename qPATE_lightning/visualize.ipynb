# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
sample = '/Users/apple/Desktop/fake_img_sample.npy'
generated = np.load(sample)

# %%
index = 0 
plt.imshow(generated[index].squeeze(0), cmap='gray')
plt.show()
